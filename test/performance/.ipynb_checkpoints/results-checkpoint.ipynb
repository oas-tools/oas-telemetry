# %%
#!pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
data = pd.read_csv("output.csv")


# Define groups
groups = [
    'NO_TLM','TLM',
    'TLM_STOPPED BEFORE_STOP', 'TLM_STOPPED WHILE_STOP', 'TLM_STOPPED AFTER_STOP',
    'NO_TLM LONG_30m', 'TLM LONG_30m'
]
print(data.shape)
data.head()
# Out:
# (123, 39)
#             Name   concurrentUsers  numberRequests   delayBetweeenRequests  \
# 0  NO_TLM ONES 1                 1             200                     100
# 1  NO_TLM ONES 2                 1             200                     100
# 2  NO_TLM ONES 3                 1             200                     100
# 3  NO_TLM ONES 4                 1             200                     100
# 4  NO_TLM ONES 5                 1             200                     100
#
#     ProblemSizePropA   ProblemSizePropB  ResultCount  ResultMin  ResultMax  \
# 0                 13                 13          200      0.916     10.984
# 1                 13                 13          200      1.290      9.721
# 2                 13                 13          200      1.236      9.652
# 3                 13                 13          200      1.516      9.056
# 4                 13                 13          200      1.232     10.886
#
# ...

# %%
# Create a graph for each group
# Loop through each column and plot a bar graph for each group

desired_columns = ["ResultMean"]
for column in ["ResultMean","used_heap_size"]:
    print(column)
    plt.figure(figsize=(15, 8))
    test_type = []
    for group in groups:
        # Filter data for the current group
        ONES = data[data['Name'].str.contains(f"{group} ONES")]
        TENS = data[data['Name'].str.contains(f"{group} TENS")]
        HUNDREDS = data[data['Name'].str.contains(f"{group} HUNDREDS")]

        # Aggregate values for the current group
        ONES_aggregated = ONES[column].mean()  # You can use other aggregation functions if needed
        # Plot the bar graph
        plt.bar(group, aggregated_values, label=group)

    # Add labels and title
    plt.xlabel('Group')
    plt.ylabel(column)
    plt.title(f'{column} RELATIVE CHANGE')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# ResultMean
# used_heap_size

# %%
group = "NO_TLM LONG_30m"


# Define the categories
categories = ["ONES", "TENS", "HUNDREDS"]

# Create a figure
plt.figure(figsize=(10, 6))

# Loop through each category and plot a line
for category in categories:
    # Filter data for the current category
    category_data = data[data['Name'].str.contains(f"{group} {category}")]
    
    # Extract column 9 values
    y_values = category_data.iloc[:, 9]
    
    # Create x values (assuming each row represents a line)
    x_values = range(len(category_data))
    
    # Plot the line
    plt.plot(x_values, y_values, marker='o', linestyle='-', label=f"{group} {category}")

# Add labels and title
plt.xlabel('Line')
plt.ylabel('Column 9 Value')
plt.title(f'Line Graph for Group {group}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Define the groups
groups = ["NO_TLM LONG_30m", "TLM LONG_30m"]

# Define the categories
categories = ["ONES", "TENS", "HUNDREDS"]

# Create a figure
plt.figure(figsize=(10, 6))

# Loop through each group
for group in groups:
    # Loop through each category and plot a line
    for category in categories:
        # Filter data for the current category and group
        category_data = data[data['Name'].str.contains(f"{group} {category}")]
        
        # Extract column 9 values
        y_values = category_data.iloc[:, 9]
        
        # Create x values (assuming each row represents a line)
        x_values = range(len(category_data))
        
        # Plot the line
        plt.plot(x_values, y_values, marker='o', linestyle='-', label=f"{group} {category}")

# Add labels and title
plt.xlabel('Line')
plt.ylabel('Column 9 Value')
plt.title('Line Graph for Groups')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
